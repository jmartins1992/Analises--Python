# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
from sklearn.model_selection import train_test_split

#data recebe através da função pd.read_csv a tabela com os dados
data=pd.read_csv("bare2d.csv", sep=";")

#Data recebe a função head e exibe os valores do objeto data.
data.transpose()
# Out:
#                            0       1       2       3       4       5    \
# Flir                    29.467  41.682  26.082  14.672  23.583  20.691
# TemperatureBulbo2(Cm)   27.400  41.400  26.400  18.500  24.000  23.500
# TemperatureBulbo5(Cm)   26.000  38.600  26.600  19.200  22.600  21.600
# TemperatureBulbo10(Cm)  24.700  33.800  26.200  20.700  21.600  20.500
# TemperatureBulbo20(Cm)  26.500  30.200  27.000  24.200  24.300  22.600
# TemperatureBulbo30(Cm)  26.400  29.000  26.500  24.200  24.000  22.600
#
#                            6       7       8      9    ...     166     167  \
# Flir                    31.751  13.044  15.451  28.74  ...  35.922  36.859
# TemperatureBulbo2(Cm)   32.400  16.800  19.200  27.50  ...  39.700  43.400
# TemperatureBulbo5(Cm)   31.100  17.600  19.600  24.60  ...  38.300  39.400
# TemperatureBulbo10(Cm)  28.600  19.300  21.400  22.80  ...  32.800  33.200
# TemperatureBulbo20(Cm)  25.800  22.700  24.200  24.00  ...  27.200  27.600
# ...

# %%
sns.set(style="darkgrid", color_codes=True)
sns.jointplot(x=data["Flir"], y=data["TemperatureBulbo2(Cm)"], kind='reg', xlim=(0, 50), ylim=(0, 50), color="#006400", size=4)


#sns.set(style="darkgrid", color_codes=True)
#sns.jointplot(x=data["SOC"], y=data["Sand"], kind='reg',  color="#006400", size=4)

#sns.set(style="darkgrid", color_codes=True)
#sns.jointplot(x=data["SOC"], y=data["Clay"], kind='reg', xlim=(0, 50), ylim=(0, 50), color="#006400", size=4)
# Out:
# C:\Users\Jeferson\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Distribuição do carbono
plt.hist(data['Flir'], bins=50)
plt.show()
#save.fig()

# %%
import seaborn as sns
import pandas as pd

sns.set(style="ticks")

data=pd.read_csv("bare2d.csv", sep=";")



df = data
sns.pairplot(df)

# %%
import numpy as np
import seaborn as sns
import pandas as pd

sns.set(style="ticks")

data=pd.read_csv("carbono.csv", sep=",")

rs = np.random.RandomState(11)
x = data['SOC']
y = data['Clay']

sns.jointplot(x, y, kind="hex", color="#4CB391")

# %%
import numpy as np
import seaborn as sns
import pandas as pd

sns.set(style="ticks")

data=pd.read_csv("carbono.csv", sep=",")

rs = np.random.RandomState(11)
x = data['SOC']
y = data['Silt']

sns.jointplot(x, y, kind="scatter", color="#4CB391")

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data=pd.read_csv("carbono.csv", sep=",")

x1 = np.array(data['SOC'])
x2 = np.array(data['Silt'])

sns.set(style="whitegrid")
rs = np.random.RandomState(50)

# Set up the matplotlib figure
f, axes = plt.subplots(3, 3, figsize=(9, 9), sharex=True, sharey=True)

# Rotate the starting point around the cubehelix hue circle
for ax, s in zip(axes.flat, np.linspace(0, 3, 10)):

    # Create a cubehelix colormap to use with kdeplot
    cmap = sns.cubehelix_palette(start=s, light=1, as_cmap=True)

    # Generate and plot a random bivariate dataset
    
    x = x1
    y = x2
    sns.kdeplot(x, y, cmap="Reds", shade=True, cut=5, ax=ax)
    ax.set(xlim=(0, 50), ylim=(0, 50))

f.tight_layout()

# %%
import numpy as np
import seaborn as sns
sns.set(style="whitegrid")

import pandas as pd

data=pd.read_csv("grass2d.csv", sep=";")
x1 = np.array(data['Flir'])
x2 = np.array(data['TemperatureBulbo2(Cm)'])

# Make an example dataset with y ~ x
rs = np.random.RandomState(7)
x = x1
y = x2

# Plot the residuals after fitting a linear model
sns.residplot(x, y, lowess=True, color="blue")

# %%
#data=pd.read_csv("grass2d.csv", sep=";")
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.
