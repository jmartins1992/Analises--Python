# %%
import sankey
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
pd.options.display.max_rows=8

# %%
df = pd.read_csv('./fruits.txt',sep = ' ',names=['true','predicted'])

# %%
df
# Out:
#           true  predicted
# 0    blueberry  blueberry
# 1        apple  blueberry
# 2    blueberry  blueberry
# 3         lime       lime
# ..         ...        ...
# 996  blueberry  blueberry
# 997      apple      apple
# 998      apple     banana
# 999     orange     orange
#
# [1000 rows x 2 columns]

# %%
colorDict =  {'apple':'#f71b1b','blueberry':'#1b7ef7','banana':'#f3f71b','lime':'#12e23f','orange':'#f78c1b'}

# %%
sankey.sankey(df['true'],df['predicted'],aspect=20,colorDict=colorDict,fontsize=10)
plt.gcf().set_size_inches(6,6)
plt.savefig('fruits.png',bbox_inches='tight',dpi=150)

# %%
import numpy as np
import pandas as pd

arquivo1 = pd.ExcelFile('diagramaSankey.xlsx')
dados1 = pd.read_excel(arquivo1,'predito')
dados3 =  pd.DataFrame(dados1)
dados3['previsto']
# Out:
# 0     neutral
# 1     neutral
# 2     neutral
# 3     neutral
#        ...
# 50    neutral
# 51    neutral
# 52    neutral
# 53    neutral
# Name: previsto, Length: 54, dtype: object

# %%
import numpy as np
import pandas as pd

arquivo1 = pd.ExcelFile('diagramaSankey.xlsx')
dados1 = pd.read_excel(arquivo1,'obs')
dados2 =  pd.DataFrame(dados1)
dados2['observado']
# Out:
# 0     neutral
# 1     neutral
# 2     neutral
# 3     neutral
#        ...
# 50    neutral
# 51    neutral
# 52    neutral
# 53    neutral
# Name: observado, Length: 54, dtype: object

# %%
colorDict =  {'neutral':'#f71b1b','lanina':'#1b7ef7','elnino':'#f3f71b'}

# %%
sankey.sankey(dados3['previsto'],dados2['observado'],aspect=20,colorDict=colorDict,fontsize=10)
plt.gcf().set_size_inches(10,10)
#plt.savefig('fruits.png',bbox_inches='tight',dpi=150)
