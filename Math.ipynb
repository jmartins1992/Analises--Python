# %%
#questão 1

import math as mt 
#Logaritmo na base 

mt.log(4,3)
# Out:
# 1.2618595071429148

# %%
#questão 2
#ln(10)

mt.log(10, mt.e)
# Out:
# 2.302585092994046

# %%
#questão3
# area = pi*r**2
#area do circulo com raio de 6.5

mt.pi*6.5**2
# Out:
# 132.73228961416876

# %%
#raiz quadrada

mt.sqrt(2500)
# Out:
# 50.0

# %%
#questão 5

#var =(25+60*3)\(14-4)^2 com 3 casas decimais

var = ((25+60*83)/(14-5)**2,3)
print(var)
# Out:
# (61.79012345679013, 3)

# %%
#fatorial de 5-
5*4*3*2*1
# Out:
# 120

# %%
mt.factorial(5)
# Out:
# 120

# %%
numero = int(input('Digite um valor :'))

fat=1

for i in range(numero):
    #print(i)
    fat = fat*(i+1)
    print(fat)
# Out:
# Digite um valor :100
# 1
# 2
# 6
# 24
# 120
# 720
# 5040
# 40320
# 362880
# 3628800
# 39916800
# 479001600
# 6227020800
# 87178291200
# 1307674368000
# 20922789888000
# 355687428096000
# 6402373705728000
# 121645100408832000
# 2432902008176640000
# 51090942171709440000
# 1124000727777607680000
# 25852016738884976640000
# 620448401733239439360000
# 15511210043330985984000000
# 403291461126605635584000000
# 10888869450418352160768000000
# 304888344611713860501504000000
# 8841761993739701954543616000000
# 265252859812191058636308480000000
# 8222838654177922817725562880000000
# 263130836933693530167218012160000000
# 8683317618811886495518194401280000000
# 295232799039604140847618609643520000000
# 10333147966386144929666651337523200000000
# 371993326789901217467999448150835200000000
# 13763753091226345046315979581580902400000000
# 523022617466601111760007224100074291200000000
# 20397882081197443358640281739902897356800000000
# 815915283247897734345611269596115894272000000000
# ...

# %%
#questão 7 seno de 30
mt.sin(mt.radians(30))
# Out:
# 0.49999999999999994

# %%
#questão 8 
#bionomio de newton (3 2): com 3 numeros, quantas combinaçoes posso fazer 

import scipy.special as sc

sc.comb(20,3)
# Out:
# 1140.0

# %%
#questão 9

#gerar um numero aleatorio inteiro entre 1 a 100

import random as rd

rd.randrange(1,100)
# Out:
# 14

# %%
#questão 10
#gerar um numero aleatorio decimal entre 1 a 100

import random as rd
nm = int(10)

for i in range (nm):
    x = rd.uniform(1,100)
    print(x)
# Out:
# 71.16880785055396
# 5.286242824879501
# 80.65875790213009
# 75.2446641733185
# 59.57771222693836
# 51.779633408878766
# 59.10292158367432
# 72.16438617858748
# 89.83838605077811
# 98.22209320038176

# %%
a = 10
b = 5.5

print('A nota máxima é',a,'para a aprovação',b)
# Out:
# A nota máxima é 10 para a aprovação 5.5

# %%
#uso de marcadores -> %
print('Nota máxima %d para aprovação e tirei %.2f' %(a,b))
print('Nota máxima %d para aprovação e tirei %2.f' %(a,b))
# Out:
# Nota máxima 10 para aprovação e tirei 5.50

# %%
c = 'Jaboticabal'

print('A cidade de analise foi %s' %c)
# Out:
# A cidade de analise foi Jaboticabak

# %%
dir('Ola mundo')
#quando for _ deve ser usado methodo(paramentro)
#quando for objeto sem paramentro
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
help()
