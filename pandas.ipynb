# %%
import pandas as pd

pseries = pd.Series([3,-5,7,5])

pseries
# Out:
# 0    3
# 1   -5
# 2    7
# 3    5
# dtype: int64

# %%
pseries2 = pd.Series([3,-3,5,8],index=['a','b','c','d'])

pseries2
# Out:
# a    3
# b   -3
# c    5
# d    8
# dtype: int64

# %%
pseries.head()
pseries.describe()
# Out:
# count    4.000000
# mean     2.500000
# std      5.259911
# min     -5.000000
# 25%      1.000000
# 50%      4.000000
# 75%      5.500000
# max      7.000000
# dtype: float64

# %%
pseries.size
# Out:
# 4

# %%
media = (pseries2['a']+pseries2['d'])/2

media
# Out:
# 5.5

# %%
media2 = (pseries[0]+pseries[3])/2
media2
# Out:
# 4.0

# %%
pseries2.keys()
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
import pandas as pd

arquivo = pd.ExcelFile('1exdadosexcel.xlsx')
dados =   pd.read_excel(arquivo,'Plan1')
dados
# Out:
#        A  B  C  D
# Maria  5  2  4  6
# Bilbo  4  4  6  3
# Sara   8  4  6  9
# José   1  8  3  4

# %%
dados1 = dados
dados2 = dados
dados3 = dados
arquivo = pd.ExcelWriter('resultados.xlsx')

dados1.to_excel(arquivo,'dados1-RESULT')
dados2.to_excel(arquivo,'dados2-RESULT')
dados3.to_excel(arquivo,'dados3-RESULT')

arquivo.save()

# %%
import pandas as pd

arquivo1 = pd.read_csv('pesquisa.csv',sep=",")
dados4 = arquivo1
arquivo1
# Out:
#             Carimbo de data/hora  \
# 0   2018/08/21 10:00:43 AM GMT-3
# 1   2018/08/21 10:00:47 AM GMT-3
# 2   2018/08/21 10:00:50 AM GMT-3
# 3   2018/08/21 10:00:50 AM GMT-3
# 4   2018/08/21 10:00:50 AM GMT-3
# 5   2018/08/21 10:00:53 AM GMT-3
# 6   2018/08/21 10:01:00 AM GMT-3
# 7   2018/08/21 10:01:02 AM GMT-3
# 8   2018/08/21 10:01:04 AM GMT-3
# 9   2018/08/21 10:01:09 AM GMT-3
# 10  2018/08/21 10:01:11 AM GMT-3
# 11  2018/08/21 10:01:11 AM GMT-3
# 12  2018/08/21 10:01:11 AM GMT-3
# 13  2018/08/21 10:01:11 AM GMT-3
# 14  2018/08/21 10:01:12 AM GMT-3
# 15  2018/08/21 10:01:12 AM GMT-3
# 16  2018/08/21 10:01:12 AM GMT-3
# 17  2018/08/21 10:01:12 AM GMT-3
# 18  2018/08/21 10:01:13 AM GMT-3
# 19  2018/08/21 10:01:14 AM GMT-3
# 20  2018/08/21 10:01:15 AM GMT-3
# 21  2018/08/21 10:01:18 AM GMT-3
# 22  2018/08/21 10:01:18 AM GMT-3
# 23  2018/08/21 10:01:21 AM GMT-3
# 24  2018/08/21 10:01:21 AM GMT-3
# 25  2018/08/21 10:01:23 AM GMT-3
# 26  2018/08/21 10:01:25 AM GMT-3
# ...

# %%
dados4.columns=['carimbo','custo','nivel']
dados4
# Out:
#                          carimbo   custo      nivel
# 0   2018/08/21 10:00:43 AM GMT-3     1.5  Doutorado
# 1   2018/08/21 10:00:47 AM GMT-3  1200.0  Doutorado
# 2   2018/08/21 10:00:50 AM GMT-3   400.0  Doutorado
# 3   2018/08/21 10:00:50 AM GMT-3   800.0  Doutorado
# 4   2018/08/21 10:00:50 AM GMT-3   650.0   Mestrado
# 5   2018/08/21 10:00:53 AM GMT-3   700.0  Doutorado
# 6   2018/08/21 10:01:00 AM GMT-3   500.0   Mestrado
# 7   2018/08/21 10:01:02 AM GMT-3   800.0  Doutorado
# 8   2018/08/21 10:01:04 AM GMT-3     2.6  Doutorado
# 9   2018/08/21 10:01:09 AM GMT-3   650.0  Doutorado
# 10  2018/08/21 10:01:11 AM GMT-3  2500.0   Mestrado
# 11  2018/08/21 10:01:11 AM GMT-3   550.0  Doutorado
# 12  2018/08/21 10:01:11 AM GMT-3   900.0  Doutorado
# 13  2018/08/21 10:01:11 AM GMT-3     1.0   Mestrado
# 14  2018/08/21 10:01:12 AM GMT-3  1000.0  Doutorado
# 15  2018/08/21 10:01:12 AM GMT-3     1.6   Mestrado
# 16  2018/08/21 10:01:12 AM GMT-3   500.0   Mestrado
# ...
